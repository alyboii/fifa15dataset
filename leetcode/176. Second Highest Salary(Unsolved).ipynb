# %%
from typing import Any

import pandas as pd
from pandas import Series, DataFrame

# %%
data = [[1, 100], [2, 200], [3, 300]]
employee = pd.DataFrame(data, columns=['id', 'salary']).astype({'id':'int64', 'salary':'int64'})

# %%
employee
# Out:
#    id  salary
# 0   1     100
# 1   2     200
# 2   3     300

# %% [markdown]
# Write a solution to find the second highest distinct salary from the Employee table. If there is no second highest salary, return null (return None in Pandas).

# %%
employee.sort_values(ascending=False,by = "salary").iloc[[1]]
# Out:
#    id  salary
# 1   2     200

# %%
import pandas as pd
import numpy as np


data = [[1, 100], [2, 200], [3, 300]]
def second_highest_salary(employee: pd.DataFrame) -> Series[Any] | DataFrame:
    if employee.empty:
        employee["SecondHighestSalary"] = np.nan
        return employee["SecondHighestSalary"]

    else :
        return employee.sort_values(ascending=False,by = "salary").iloc[[1]]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 6
#       2 import numpy as np
#       5 data = [[1, 100], [2, 200], [3, 300]]
# ----> 6 def second_highest_salary(employee: pd.DataFrame) -> Series[Any] | DataFrame:
#       7     if employee.empty:
#       8         employee["SecondHighestSalary"] = np.nan
#
# NameError: name 'Series' is not defined
