# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('display.max_columns', 50)
pd.set_option('display.width', 200)

# %%
df = pd.read_csv("players_15.csv",low_memory=False)
df.reset_index()
# yaş, boy, kilo, lig, kulüp), genel ratingler (overall, potential
# Out:
#        index  sofifa_id                                         player_url         short_name                            long_name player_positions  overall  potential    value_eur  wage_eur  age  \
# 0          0     158023  https://sofifa.com/player/158023/lionel-messi/...           L. Messi       Lionel Andrés Messi Cuccittini               CF       93         95  100500000.0  550000.0   27
# 1          1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro           LW, LM       92         92   79000000.0  375000.0   29
# 2          2       9014  https://sofifa.com/player/9014/arjen-robben/15...          A. Robben                         Arjen Robben       RM, LM, RW       90         90   54500000.0  275000.0   30
# 3          3      41236  https://sofifa.com/player/41236/zlatan-ibrahim...     Z. Ibrahimović                   Zlatan Ibrahimović               ST       90         90   52500000.0  275000.0   32
# ...

# %%
df.columns
# Out:
# Index(['sofifa_id', 'player_url', 'short_name', 'long_name', 'player_positions', 'overall', 'potential', 'value_eur', 'wage_eur', 'age',
#        ...
#        'lcb', 'cb', 'rcb', 'rb', 'gk', 'player_face_url', 'club_logo_url', 'club_flag_url', 'nation_logo_url', 'nation_flag_url'],
#       dtype='object', length=110)

# %%
df.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16155 entries, 0 to 16154
# Data columns (total 110 columns):
#  #    Column                       Non-Null Count  Dtype
# ---   ------                       --------------  -----
#  0    sofifa_id                    16155 non-null  int64
#  1    player_url                   16155 non-null  object
#  2    short_name                   16155 non-null  object
#  3    long_name                    16155 non-null  object
#  4    player_positions             16155 non-null  object
#  5    overall                      16155 non-null  int64
#  6    potential                    16155 non-null  int64
#  7    value_eur                    15844 non-null  float64
#  8    wage_eur                     15916 non-null  float64
#  9    age                          16155 non-null  int64
#  10   dob                          16155 non-null  object
#  11   height_cm                    16155 non-null  int64
# ...

# %%
df.isna().sum()
# Out:
# sofifa_id               0
# player_url              0
# short_name              0
# long_name               0
# player_positions        0
#                     ...
# player_face_url         0
# club_logo_url         239
# club_flag_url         239
# nation_logo_url     15074
# nation_flag_url         0
# Length: 110, dtype: int64

# %%
df.groupby("nationality_name")["sofifa_id"].count().sort_values(ascending=False).head(5)
# Out:
# nationality_name
# England      1627
# Spain        1051
# France        958
# Argentina     867
# Italy         795
# Name: sofifa_id, dtype: int64

# %%
for x in df.columns:
    print(df[x].info())
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 16155 entries, 0 to 16154
# Series name: sofifa_id
# Non-Null Count  Dtype
# --------------  -----
# 16155 non-null  int64
# dtypes: int64(1)
# memory usage: 126.3 KB
# None
# <class 'pandas.core.series.Series'>
# RangeIndex: 16155 entries, 0 to 16154
# Series name: player_url
# Non-Null Count  Dtype
# --------------  -----
# 16155 non-null  object
# dtypes: object(1)
# memory usage: 126.3+ KB
# None
# <class 'pandas.core.series.Series'>
# RangeIndex: 16155 entries, 0 to 16154
# Series name: short_name
# Non-Null Count  Dtype
# --------------  -----
# 16155 non-null  object
# dtypes: object(1)
# memory usage: 126.3+ KB
# None
# <class 'pandas.core.series.Series'>
# RangeIndex: 16155 entries, 0 to 16154
# Series name: long_name
# Non-Null Count  Dtype
# --------------  -----
# 16155 non-null  object
# dtypes: object(1)
# memory usage: 126.3+ KB
# None
# <class 'pandas.core.series.Series'>
# RangeIndex: 16155 entries, 0 to 16154
# ...

# %%
df_who = df[["sofifa_id","short_name"]]
df_who.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16155 entries, 0 to 16154
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   sofifa_id   16155 non-null  int64
#  1   short_name  16155 non-null  object
# dtypes: int64(1), object(1)
# memory usage: 252.6+ KB

# %%
df_meta = df[["age","height_cm","weight_kg","club_name"]]
